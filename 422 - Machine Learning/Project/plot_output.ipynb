# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates

# %%
df_combined = pd.read_csv('df_combined.csv')

# %%
df = df_combined
df['date'] = pd.to_datetime(df['date']) # ensure the date column is datetime

# Plot for op_nxt
plt.figure(figsize=(12,8))
plt.plot(df['date'], df['op_nxt_actual'], label='Actual')
plt.plot(df['date'], df['op_nxt_predicted'], label='Predicted')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.title('op_nxt: Predicted vs Actual')
plt.ylabel('op_nxt')
plt.xlabel('date')
plt.gcf().autofmt_xdate() # Rotation
plt.legend()
plt.show()

# %%
# Plot for hi_nxt
plt.figure(figsize=(12, 8))
plt.plot(df['date'], df['hi_nxt_actual'], label='Actual')
plt.plot(df['date'], df['hi_nxt_predicted'], label='Predicted')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.title('hi_nxt: Predicted vs Actual')
plt.ylabel('hi_nxt')
plt.xlabel('date')
plt.gcf().autofmt_xdate() # Rotation
plt.legend()
plt.show()

# %%
# Plot for lo_nxt
plt.figure(figsize=(12, 8))
plt.plot(df['date'], df['lo_nxt_actual'], label='Actual')
plt.plot(df['date'], df['lo_nxt_predicted'], label='Predicted')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.title('lo_nxt: Predicted vs Actual')
plt.ylabel('lo_nxt')
plt.xlabel('date')
plt.gcf().autofmt_xdate() # Rotation
plt.legend()
plt.show()

# %%
# Plot for cl_nxt
plt.figure(figsize=(12, 8))
plt.plot(df['date'], df['cl_nxt_actual'], label='Actual')
plt.plot(df['date'], df['cl_nxt_predicted'], label='Predicted')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.title('cl_nxt: Predicted vs Actual')
plt.ylabel('cl_nxt')
plt.xlabel('date')
plt.gcf().autofmt_xdate() # Rotation
plt.legend()
plt.show()
