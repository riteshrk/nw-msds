# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/NorthwesternHeader.png?raw=1" />

# %% [markdown]
# ## MSDS458 Research Assignment 02 - Part 1
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import datetime
from packaging import version

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as k

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Verify TensorFlow Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.15.0

# %% [markdown]
# ## Mount Google Drive to Colab Environment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## EDA Functions

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)

    x = x[indices]
    y = y[indices]

    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)

    x = x[indices]
    y = y[indices]

    y = tf.keras.utils.to_categorical(y)

    return x, y

# %%
def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)

    x = x[indices]
    y = y[indices]
    p = p[indices]

    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

# %% [markdown]
# ## Research Assignment Reporting Functions

# %%
def plot_history(history):
  losses = history.history['loss']
  accs = history.history['accuracy']
  val_losses = history.history['val_loss']
  val_accs = history.history['val_accuracy']
  epochs = len(losses)

  plt.figure(figsize=(16, 4))
  for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
  plt.show()

def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(16,12))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ## Review Labels

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ## Plot Subset of Examples

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ## Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog'
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ## Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ## Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ## Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %% [markdown]
# ## Create the Model

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/CNN_architecture_v4.png?raw=1">

# %% [markdown]
# ## Experiment 4: Build CNN Model

# %% [markdown]
# CNN with 3 convolution/max pooling (without normalization) layers

# %%
k.clear_session()
# Create the model
model = Sequential([
    Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation='relu', input_shape=x_train_norm.shape[1:]),
    MaxPool2D((2, 2), strides=2),
    Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation='relu'),
    MaxPool2D((2, 2), strides=2),
    Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation='relu'),
    MaxPool2D((2, 2), strides=2),
    Flatten(),
    Dense(units=384, activation='relu'),
    Dense(units=10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 128)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 384)               786816
#
#  dense_1 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 2269578 (8.66 MB)
# Trainable params: 2269578 (8.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)

# %% [markdown]
# ## Compiling the model

# %% [markdown]
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.losses.SparseCategoricalCrossentropy</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy</div>

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Module: tf.keras.callbacks</b></div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.EarlyStopping</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.ModelCheckpoint</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint</div>

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=64
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                     tf.keras.callbacks.ModelCheckpoint("CNN_model.h5",save_best_only=True,save_weights_only=False)
                     ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    ]
                   )
# Out:
# Epoch 1/200
# 704/704 [==============================] - 12s 11ms/step - loss: 1.4780 - accuracy: 0.4616 - val_loss: 1.2699 - val_accuracy: 0.5562
# Epoch 2/200
#   7/704 [..............................] - ETA: 6s - loss: 1.1863 - accuracy: 0.5871
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 704/704 [==============================] - 7s 10ms/step - loss: 1.0351 - accuracy: 0.6393 - val_loss: 0.9748 - val_accuracy: 0.6578
# Epoch 3/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.8336 - accuracy: 0.7101 - val_loss: 0.9420 - val_accuracy: 0.6698
# Epoch 4/200
# 704/704 [==============================] - 7s 11ms/step - loss: 0.6863 - accuracy: 0.7604 - val_loss: 0.7833 - val_accuracy: 0.7342
# Epoch 5/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.5614 - accuracy: 0.8043 - val_loss: 0.7795 - val_accuracy: 0.7318
# Epoch 6/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.4562 - accuracy: 0.8402 - val_loss: 0.7641 - val_accuracy: 0.7508
# Epoch 7/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.3604 - accuracy: 0.8738 - val_loss: 0.8997 - val_accuracy: 0.7222
# Epoch 8/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.2824 - accuracy: 0.8995 - val_loss: 0.8765 - val_accuracy: 0.7544
# Epoch 9/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.2068 - accuracy: 0.9268 - val_loss: 1.0132 - val_accuracy: 0.7350
# Epoch 10/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.1711 - accuracy: 0.9401 - val_loss: 1.1296 - val_accuracy: 0.7420
# Epoch 11/200
# 704/704 [==============================] - 7s 10ms/step - loss: 0.1393 - accuracy: 0.9517 - val_loss: 1.1566 - val_accuracy: 0.7458

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set. This is easy to do, we simply use the `evaluate` method on our model.

# %%
model = tf.keras.models.load_model("CNN_model.h5")
print(f"Test acc: {model.evaluate(x_test_norm, y_test)[1]:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8123 - accuracy: 0.7421
# Test acc: 0.742

# %% [markdown]
# ## Predictions

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# shape of preds:  (10000, 10)

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 6   0.360     0.874     0.900         0.722
# 7   0.282     0.900     0.877         0.754
# 8   0.207     0.927     1.013         0.735
# 9   0.171     0.940     1.130         0.742
# 10  0.139     0.952     1.157         0.746

# %% [markdown]
# ## Plot Training Metrics (Loss and Accuracy)

# %%
plt.subplots(figsize=(16,12))
plt.tight_layout()
display_training_curves(history_df['accuracy'], history_df['val_accuracy'], 'accuracy', 211)
display_training_curves(history_df['loss'], history_df['val_loss'], 'loss', 212)
# Out:
# <ipython-input-7-353fbae40d9a>:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(subplot)

# %% [markdown]
# ## Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.82      0.77      1000
#            1       0.88      0.83      0.86      1000
#            2       0.72      0.57      0.64      1000
#            3       0.60      0.54      0.57      1000
#            4       0.69      0.70      0.69      1000
#            5       0.61      0.69      0.65      1000
#            6       0.74      0.87      0.80      1000
#            7       0.78      0.78      0.78      1000
#            8       0.87      0.80      0.83      1000
#            9       0.83      0.81      0.82      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.74     10000
# weighted avg       0.74      0.74      0.74     10000
#
# Accuracy Score: 0.7421
# Root Mean Square Error: 2.0982373554962748

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# ## Load HDF5 Model Format

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.models.load_model</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model</div>

# %%
model = tf.keras.models.load_model('CNN_model.h5')

# %%
preds = model.predict(x_test_norm)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# ## Predictions

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

# %%
df = pd.DataFrame(preds[0:20], columns = ['airplane'
                                          ,'automobile'
                                          ,'bird'
                                          ,'cat'
                                          ,'deer'
                                          ,'dog'
                                          ,'frog'
                                          ,'horse'
                                          ,'ship'
                                          ,'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_029a9_row0_col0, #T_029a9_row6_col0, #T_029a9_row12_col7, #T_029a9_row15_col1, #T_029a9_row15_col3 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_029a9_row0_col1, #T_029a9_row2_col4, #T_029a9_row3_col8, #T_029a9_row8_col0, #T_029a9_row10_col6, #T_029a9_row10_col8 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_029a9_row0_col2 {
#   background-color: #90a0e7;
#   color: #f1f1f1;
# }
# #T_029a9_row0_col3 {
#   background-color: #a6b2e9;
#   color: #000000;
# }
# #T_029a9_row0_col4, #T_029a9_row0_col7, #T_029a9_row0_col8, #T_029a9_row0_col9, #T_029a9_row1_col0, #T_029a9_row1_col2, #T_029a9_row1_col3, #T_029a9_row1_col4, #T_029a9_row1_col5, #T_029a9_row1_col6, #T_029a9_row1_col7, #T_029a9_row1_col9, #T_029a9_row2_col5, #T_029a9_row2_col6, #T_029a9_row3_col1, #T_029a9_row3_col2, #T_029a9_row3_col3, #T_029a9_row3_col4, #T_029a9_row3_col5, #T_029a9_row3_col6, #T_029a9_row3_col7, #T_029a9_row3_col9, #T_029a9_row4_col0, #T_029a9_row4_col1, #T_029a9_row4_col3, #T_029a9_row4_col5, #T_029a9_row4_col7, #T_029a9_row4_col8, #T_029a9_row4_col9, #T_029a9_row5_col0, #T_029a9_row5_col1, #T_029a9_row5_col2, #T_029a9_row5_col3, #T_029a9_row5_col4, #T_029a9_row5_col5, #T_029a9_row5_col7, #T_029a9_row5_col8, #T_029a9_row5_col9, #T_029a9_row6_col4, #T_029a9_row6_col5, #T_029a9_row6_col6, #T_029a9_row6_col7, #T_029a9_row6_col8, #T_029a9_row7_col0, #T_029a9_row7_col1, #T_029a9_row7_col3, #T_029a9_row7_col5, #T_029a9_row7_col7, #T_029a9_row7_col8, #T_029a9_row7_col9, #T_029a9_row8_col1, #T_029a9_row8_col8, #T_029a9_row8_col9, #T_029a9_row9_col0, #T_029a9_row9_col2, #T_029a9_row9_col3, #T_029a9_row9_col4, #T_029a9_row9_col5, #T_029a9_row9_col6, #T_029a9_row9_col7, #T_029a9_row9_col8, #T_029a9_row10_col1, #T_029a9_row10_col9, #T_029a9_row11_col0, #T_029a9_row11_col1, #T_029a9_row11_col2, #T_029a9_row11_col3, #T_029a9_row11_col4, #T_029a9_row11_col5, #T_029a9_row11_col6, #T_029a9_row11_col7, #T_029a9_row11_col8, #T_029a9_row12_col0, #T_029a9_row12_col1, #T_029a9_row12_col8, #T_029a9_row12_col9, #T_029a9_row13_col0, #T_029a9_row13_col1, #T_029a9_row13_col2, #T_029a9_row13_col3, #T_029a9_row13_col4, #T_029a9_row13_col5, #T_029a9_row13_col6, #T_029a9_row13_col8, #T_029a9_row13_col9, #T_029a9_row14_col0, #T_029a9_row14_col1, #T_029a9_row14_col2, #T_029a9_row14_col3, #T_029a9_row14_col4, #T_029a9_row14_col5, #T_029a9_row14_col6, #T_029a9_row14_col7, #T_029a9_row14_col8, #T_029a9_row15_col5, #T_029a9_row15_col7, #T_029a9_row15_col9, #T_029a9_row16_col0, #T_029a9_row16_col1, #T_029a9_row16_col4, #T_029a9_row16_col6, #T_029a9_row16_col7, #T_029a9_row16_col8, #T_029a9_row16_col9, #T_029a9_row17_col0, #T_029a9_row17_col1, #T_029a9_row17_col2, #T_029a9_row17_col6, #T_029a9_row17_col8, #T_029a9_row17_col9, #T_029a9_row18_col0, #T_029a9_row18_col1, #T_029a9_row18_col2, #T_029a9_row18_col3, #T_029a9_row18_col4, #T_029a9_row18_col5, #T_029a9_row18_col6, #T_029a9_row18_col7, #T_029a9_row18_col9, #T_029a9_row19_col0, #T_029a9_row19_col1, #T_029a9_row19_col2, #T_029a9_row19_col3, #T_029a9_row19_col4, #T_029a9_row19_col5, #T_029a9_row19_col7, #T_029a9_row19_col8, #T_029a9_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_029a9_row0_col5 {
#   background-color: #b2bdeb;
#   color: #000000;
# }
# #T_029a9_row0_col6, #T_029a9_row2_col3, #T_029a9_row2_col7, #T_029a9_row10_col3, #T_029a9_row15_col0, #T_029a9_row17_col4 {
#   background-color: #edeef2;
#   color: #000000;
# }
# #T_029a9_row1_col1 {
#   background-color: #d3d8ef;
#   color: #000000;
# }
# #T_029a9_row1_col8, #T_029a9_row10_col0 {
#   background-color: #8d9ee6;
#   color: #f1f1f1;
# }
# #T_029a9_row2_col0 {
#   background-color: #e8eaf1;
#   color: #000000;
# }
# #T_029a9_row2_col1 {
#   background-color: #c5cded;
#   color: #000000;
# }
# #T_029a9_row2_col2, #T_029a9_row6_col3 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_029a9_row2_col8, #T_029a9_row8_col2 {
#   background-color: #ced4ee;
#   color: #000000;
# }
# #T_029a9_row2_col9 {
#   background-color: #c8cfed;
#   color: #000000;
# }
# #T_029a9_row3_col0, #T_029a9_row4_col4, #T_029a9_row5_col6, #T_029a9_row6_col1, #T_029a9_row8_col3, #T_029a9_row11_col9, #T_029a9_row12_col2, #T_029a9_row13_col7, #T_029a9_row14_col9, #T_029a9_row16_col5, #T_029a9_row18_col8, #T_029a9_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_029a9_row4_col2, #T_029a9_row8_col5 {
#   background-color: #dce0f0;
#   color: #000000;
# }
# #T_029a9_row4_col6 {
#   background-color: #b0bbea;
#   color: #000000;
# }
# #T_029a9_row6_col2 {
#   background-color: #7c90e4;
#   color: #f1f1f1;
# }
# #T_029a9_row6_col9 {
#   background-color: #dde0f0;
#   color: #000000;
# }
# #T_029a9_row7_col2 {
#   background-color: #bec7ec;
#   color: #000000;
# }
# #T_029a9_row7_col4, #T_029a9_row17_col5 {
#   background-color: #e7e9f1;
#   color: #000000;
# }
# #T_029a9_row7_col6 {
#   background-color: #7e92e4;
#   color: #f1f1f1;
# }
# #T_029a9_row8_col4, #T_029a9_row12_col3 {
#   background-color: #eaebf1;
#   color: #000000;
# }
# #T_029a9_row8_col6 {
#   background-color: #e5e7f1;
#   color: #000000;
# }
# #T_029a9_row8_col7, #T_029a9_row10_col5, #T_029a9_row12_col6, #T_029a9_row17_col3 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_029a9_row9_col1 {
#   background-color: #d7dbef;
#   color: #000000;
# }
# #T_029a9_row9_col9 {
#   background-color: #8b9ce6;
#   color: #f1f1f1;
# }
# #T_029a9_row10_col2 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_029a9_row10_col4 {
#   background-color: #d1d6ee;
#   color: #000000;
# }
# #T_029a9_row10_col7, #T_029a9_row16_col2 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_029a9_row12_col4 {
#   background-color: #dfe2f0;
#   color: #000000;
# }
# #T_029a9_row12_col5 {
#   background-color: #8899e6;
#   color: #f1f1f1;
# }
# #T_029a9_row15_col2 {
#   background-color: #b4beeb;
#   color: #000000;
# }
# #T_029a9_row15_col4, #T_029a9_row15_col6 {
#   background-color: #bbc4ec;
#   color: #000000;
# }
# #T_029a9_row15_col8 {
#   background-color: #cfd5ee;
#   color: #000000;
# }
# #T_029a9_row16_col3 {
#   background-color: #e6e8f1;
#   color: #000000;
# }
# #T_029a9_row17_col7 {
#   background-color: #8295e5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_029a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_029a9_level0_col0" class="col_heading level0 col0" >airplane</th>
#       <th id="T_029a9_level0_col1" class="col_heading level0 col1" >automobile</th>
#       <th id="T_029a9_level0_col2" class="col_heading level0 col2" >bird</th>
#       <th id="T_029a9_level0_col3" class="col_heading level0 col3" >cat</th>
#       <th id="T_029a9_level0_col4" class="col_heading level0 col4" >deer</th>
#       <th id="T_029a9_level0_col5" class="col_heading level0 col5" >dog</th>
#       <th id="T_029a9_level0_col6" class="col_heading level0 col6" >frog</th>
#       <th id="T_029a9_level0_col7" class="col_heading level0 col7" >horse</th>
#       <th id="T_029a9_level0_col8" class="col_heading level0 col8" >ship</th>
#       <th id="T_029a9_level0_col9" class="col_heading level0 col9" >truck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_029a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_029a9_row0_col0" class="data row0 col0" >1.82%</td>
#       <td id="T_029a9_row0_col1" class="data row0 col1" >0.52%</td>
#       <td id="T_029a9_row0_col2" class="data row0 col2" >4.59%</td>
#       <td id="T_029a9_row0_col3" class="data row0 col3" >42.68%</td>
#       <td id="T_029a9_row0_col4" class="data row0 col4" >0.06%</td>
#       <td id="T_029a9_row0_col5" class="data row0 col5" >47.41%</td>
#       <td id="T_029a9_row0_col6" class="data row0 col6" >2.50%</td>
#       <td id="T_029a9_row0_col7" class="data row0 col7" >0.18%</td>
#       <td id="T_029a9_row0_col8" class="data row0 col8" >0.05%</td>
#       <td id="T_029a9_row0_col9" class="data row0 col9" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_029a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_029a9_row1_col0" class="data row1 col0" >0.27%</td>
#       <td id="T_029a9_row1_col1" class="data row1 col1" >18.23%</td>
#       <td id="T_029a9_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_029a9_row1_co

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog'
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of all layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# Get activation values for the last dense layer
activations = activation_model.predict(x_valid_norm[:2000])
dense_layer_activations = activations[-3]
output_layer_activations = activations[-1]
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %% [markdown]
# # sklearn.manifold.TSNE

# %%
# Reduce the dimension using T-SNE to visualize i n a scatterplot
tsne = TSNE(n_components=2, verbose=1, init='pca', learning_rate='auto', perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(dense_layer_activations)

# Scaling
tsne_results = (tsne_results - tsne_results.min()) / (tsne_results.max() - tsne_results.min())
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.002s...
# [t-SNE] Computed neighbors for 2000 samples in 0.233s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 1.848435
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.503761
# [t-SNE] KL divergence after 300 iterations: 2.446973

# %%
cmap = plt.cm.tab10
plt.figure(figsize=(16,10))
scatter = plt.scatter(tsne_results[:,0],tsne_results[:,1], c=y_valid_split[:2000], s=10, cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=class_names)

image_positions = np.array([[1., 1.]])
for index, position in enumerate(tsne_results):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(x_train[index], cmap="binary"),
            position, bboxprops={"lw": 1})
        plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()

# %%
# Time Stamp
current_time = datetime.datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")

# Print the formatted time
print("Last Run:", formatted_time)
# Out:
# Last Run: 2024-06-11 17:32:10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !jupyter nbconvert --to html "/content/drive/MyDrive/Colab Notebooks/458_Assignment_E4_A.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/458_Assignment_E4_A.ipynb to html
# [NbConvertApp] Writing 1544127 bytes to /content/drive/MyDrive/Colab Notebooks/458_Assignment_E4_A.html
