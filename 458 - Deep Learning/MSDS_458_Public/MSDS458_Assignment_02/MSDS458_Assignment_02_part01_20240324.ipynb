# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/NorthwesternHeader.png?raw=1" />

# %% [markdown]
# ## MSDS458 Research Assignment 02 - Part 1
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import datetime
from packaging import version

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as k

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Verify TensorFlow Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.15.0

# %% [markdown]
# ## Mount Google Drive to Colab Environment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## EDA Functions

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)

    x = x[indices]
    y = y[indices]

    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)

    x = x[indices]
    y = y[indices]

    y = tf.keras.utils.to_categorical(y)

    return x, y

# %%
def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)

    x = x[indices]
    y = y[indices]
    p = p[indices]

    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

# %% [markdown]
# ## Research Assignment Reporting Functions

# %%
def plot_history(history):
  losses = history.history['loss']
  accs = history.history['accuracy']
  val_losses = history.history['val_loss']
  val_accs = history.history['val_accuracy']
  epochs = len(losses)

  plt.figure(figsize=(16, 4))
  for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
  plt.show()

def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(16,12))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 8s 0us/step

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ## Review Labels

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ## Plot Subset of Examples

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ## Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog'
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ## Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ## Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ## Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %% [markdown]
# ## Create the Model

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/CNN_architecture_v4.png?raw=1">

# %% [markdown]
# ## Build CNN Model

# %% [markdown]
# We use a Sequential class defined in Keras to create our model. The first 9 layers Conv2D MaxPooling, Dropout handle feature learning.  The last 3 layers, handle classification

# %%
k.clear_session()
model = Sequential([
  Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=x_train_norm.shape[1:]),
  MaxPool2D((2, 2),strides=2),
  Dropout(0.3),
  Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu),
  MaxPool2D((2, 2),strides=2),
  Dropout(0.3),
  Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu),
  MaxPool2D((2, 2),strides=2),
  Dropout(0.3),
  Flatten(),
  Dense(units=384,activation=tf.nn.softmax,kernel_regularizer=tf.keras.regularizers.L2(0.001)),
  BatchNormalization(),
  Dropout(0.3),
  Dense(units=10, activation=tf.nn.softmax)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 384)               786816
#
#  batch_normalization (Batch  (None, 384)               1536
#  Normalization)
#
#  dropout_3 (Dropout)         (None, 384)               0
#
#  dense_1 (Dense)             (None, 10)                3850
#
# =================================================================
# Total params: 2271114 (8.66 MB)
# Trainable params: 2270346 (8.66 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)

# %% [markdown]
# ## Compiling the model

# %% [markdown]
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.losses.SparseCategoricalCrossentropy</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy</div>

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Module: tf.keras.callbacks</b></div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.EarlyStopping</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.callbacks.ModelCheckpoint</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint</div>

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=64
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                     tf.keras.callbacks.ModelCheckpoint("CNN_model.h5",save_best_only=True,save_weights_only=False)
                     ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    ]
                   )
# Out:
# Epoch 1/200
# 704/704 [==============================] - 16s 14ms/step - loss: 1.6876 - accuracy: 0.4160 - val_loss: 1.6629 - val_accuracy: 0.4496
# Epoch 2/200
#   6/704 [..............................] - ETA: 8s - loss: 1.5320 - accuracy: 0.4531
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 704/704 [==============================] - 9s 12ms/step - loss: 1.3324 - accuracy: 0.5587 - val_loss: 1.1896 - val_accuracy: 0.6160
# Epoch 3/200
# 704/704 [==============================] - 9s 12ms/step - loss: 1.1931 - accuracy: 0.6152 - val_loss: 1.2931 - val_accuracy: 0.5638
# Epoch 4/200
# 704/704 [==============================] - 9s 13ms/step - loss: 1.0976 - accuracy: 0.6533 - val_loss: 1.1998 - val_accuracy: 0.6160
# Epoch 5/200
# 704/704 [==============================] - 9s 13ms/step - loss: 1.0323 - accuracy: 0.6792 - val_loss: 1.0089 - val_accuracy: 0.6940
# Epoch 6/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.9700 - accuracy: 0.7021 - val_loss: 0.9473 - val_accuracy: 0.6968
# Epoch 7/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.9345 - accuracy: 0.7166 - val_loss: 0.8846 - val_accuracy: 0.7286
# Epoch 8/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.8919 - accuracy: 0.7298 - val_loss: 0.8524 - val_accuracy: 0.7386
# Epoch 9/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.8658 - accuracy: 0.7421 - val_loss: 0.9864 - val_accuracy: 0.7078
# Epoch 10/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.8392 - accuracy: 0.7523 - val_loss: 0.8040 - val_accuracy: 0.7630
# Epoch 11/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.8129 - accuracy: 0.7608 - val_loss: 0.8505 - val_accuracy: 0.7428
# Epoch 12/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.7931 - accuracy: 0.7669 - val_loss: 0.7970 - val_accuracy: 0.7694
# Epoch 13/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.7741 - accuracy: 0.7694 - val_loss: 0.7430 - val_accuracy: 0.7838
# Epoch 14/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.7592 - accuracy: 0.7760 - val_loss: 0.7791 - val_accuracy: 0.7644
# Epoch 15/200
# 704/704 [==============================] - 9s 13ms/step - loss: 0.7434 - accuracy: 0.7825 - val_loss: 0.7834 - val_accuracy: 0.7782
# Epoch 16/200
# 704/704 [==============================] - 9s 12ms/step - loss: 0.7229 - accuracy: 0.7895 - val_loss: 0.7852 - val_accuracy: 0.7684

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set. This is easy to do, we simply use the `evaluate` method on our model.

# %%
model = tf.keras.models.load_model("CNN_model.h5")
print(f"Test acc: {model.evaluate(x_test_norm, y_test)[1]:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7687 - accuracy: 0.7749
# Test acc: 0.775

# %% [markdown]
# ## Predictions

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# shape of preds:  (10000, 10)

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 11  0.793     0.767     0.797         0.769
# 12  0.774     0.769     0.743         0.784
# 13  0.759     0.776     0.779         0.764
# 14  0.743     0.783     0.783         0.778
# 15  0.723     0.789     0.785         0.768

# %% [markdown]
# ## Plot Training Metrics (Loss and Accuracy)

# %%
plt.subplots(figsize=(16,12))
plt.tight_layout()
display_training_curves(history_df['accuracy'], history_df['val_accuracy'], 'accuracy', 211)
display_training_curves(history_df['loss'], history_df['val_loss'], 'loss', 212)
# Out:
# <ipython-input-7-353fbae40d9a>:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(subplot)

# %% [markdown]
# ## Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79      1000
#            1       0.91      0.87      0.89      1000
#            2       0.74      0.61      0.67      1000
#            3       0.57      0.67      0.61      1000
#            4       0.77      0.70      0.73      1000
#            5       0.73      0.65      0.69      1000
#            6       0.79      0.86      0.82      1000
#            7       0.84      0.78      0.81      1000
#            8       0.83      0.89      0.86      1000
#            9       0.89      0.84      0.87      1000
#
#     accuracy                           0.77     10000
#    macro avg       0.78      0.77      0.77     10000
# weighted avg       0.78      0.77      0.77     10000
#
# Accuracy Score: 0.7749
# Root Mean Square Error: 1.9260062305195171

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# ## Load HDF5 Model Format

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.models.load_model</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model</div>

# %%
model = tf.keras.models.load_model('CNN_model.h5')

# %%
preds = model.predict(x_test_norm)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# ## Predictions

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

# %%
df = pd.DataFrame(preds[0:20], columns = ['airplane'
                                          ,'automobile'
                                          ,'bird'
                                          ,'cat'
                                          ,'deer'
                                          ,'dog'
                                          ,'frog'
                                          ,'horse'
                                          ,'ship'
                                          ,'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_12b04_row0_col0, #T_12b04_row8_col7, #T_12b04_row9_col0, #T_12b04_row10_col9, #T_12b04_row18_col0 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_12b04_row0_col1, #T_12b04_row0_col7, #T_12b04_row0_col9, #T_12b04_row1_col2, #T_12b04_row1_col3, #T_12b04_row1_col4, #T_12b04_row1_col5, #T_12b04_row1_col6, #T_12b04_row1_col7, #T_12b04_row2_col3, #T_12b04_row2_col4, #T_12b04_row2_col5, #T_12b04_row2_col6, #T_12b04_row2_col7, #T_12b04_row3_col3, #T_12b04_row3_col5, #T_12b04_row3_col6, #T_12b04_row3_col7, #T_12b04_row4_col0, #T_12b04_row4_col1, #T_12b04_row4_col5, #T_12b04_row4_col7, #T_12b04_row4_col8, #T_12b04_row4_col9, #T_12b04_row5_col0, #T_12b04_row5_col1, #T_12b04_row5_col4, #T_12b04_row5_col5, #T_12b04_row5_col7, #T_12b04_row5_col8, #T_12b04_row5_col9, #T_12b04_row6_col0, #T_12b04_row6_col3, #T_12b04_row6_col4, #T_12b04_row6_col5, #T_12b04_row6_col6, #T_12b04_row6_col7, #T_12b04_row6_col8, #T_12b04_row7_col1, #T_12b04_row7_col9, #T_12b04_row8_col0, #T_12b04_row8_col1, #T_12b04_row8_col8, #T_12b04_row8_col9, #T_12b04_row9_col3, #T_12b04_row9_col4, #T_12b04_row9_col5, #T_12b04_row9_col6, #T_12b04_row9_col7, #T_12b04_row9_col8, #T_12b04_row10_col1, #T_12b04_row10_col5, #T_12b04_row10_col6, #T_12b04_row11_col0, #T_12b04_row11_col1, #T_12b04_row11_col2, #T_12b04_row11_col3, #T_12b04_row11_col4, #T_12b04_row11_col5, #T_12b04_row11_col6, #T_12b04_row11_col7, #T_12b04_row11_col8, #T_12b04_row12_col0, #T_12b04_row12_col1, #T_12b04_row12_col8, #T_12b04_row12_col9, #T_12b04_row13_col0, #T_12b04_row13_col1, #T_12b04_row13_col2, #T_12b04_row13_col3, #T_12b04_row13_col6, #T_12b04_row13_col8, #T_12b04_row13_col9, #T_12b04_row14_col0, #T_12b04_row14_col2, #T_12b04_row14_col3, #T_12b04_row14_col4, #T_12b04_row14_col5, #T_12b04_row14_col6, #T_12b04_row14_col7, #T_12b04_row15_col3, #T_12b04_row15_col5, #T_12b04_row15_col7, #T_12b04_row15_col9, #T_12b04_row16_col0, #T_12b04_row16_col1, #T_12b04_row16_col2, #T_12b04_row16_col4, #T_12b04_row16_col6, #T_12b04_row16_col7, #T_12b04_row16_col8, #T_12b04_row16_col9, #T_12b04_row18_col1, #T_12b04_row18_col2, #T_12b04_row18_col3, #T_12b04_row18_col4, #T_12b04_row18_col5, #T_12b04_row18_col6, #T_12b04_row18_col7, #T_12b04_row18_col9, #T_12b04_row19_col0, #T_12b04_row19_col1, #T_12b04_row19_col3, #T_12b04_row19_col5, #T_12b04_row19_col7, #T_12b04_row19_col8, #T_12b04_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_12b04_row0_col2 {
#   background-color: #e7e9f1;
#   color: #000000;
# }
# #T_12b04_row0_col3, #T_12b04_row5_col6, #T_12b04_row6_col1, #T_12b04_row7_col2, #T_12b04_row8_col3, #T_12b04_row10_col0, #T_12b04_row11_col9, #T_12b04_row12_col4, #T_12b04_row13_col7, #T_12b04_row16_col5, #T_12b04_row18_col8, #T_12b04_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_12b04_row0_col4, #T_12b04_row0_col6, #T_12b04_row2_col2, #T_12b04_row12_col7, #T_12b04_row17_col0, #T_12b04_row17_col1, #T_12b04_row19_col2, #T_12b04_row19_col4 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_12b04_row0_col5, #T_12b04_row0_col8, #T_12b04_row2_col9, #T_12b04_row3_col1, #T_12b04_row17_col8 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_12b04_row1_col0 {
#   background-color: #d8ddef;
#   color: #000000;
# }
# #T_12b04_row1_col1 {
#   background-color: #abb7ea;
#   color: #000000;
# }
# #T_12b04_row1_col8 {
#   background-color: #b0bbea;
#   color: #000000;
# }
# #T_12b04_row1_col9, #T_12b04_row8_col5, #T_12b04_row12_col6, #T_12b04_row15_col1, #T_12b04_row15_col4, #T_12b04_row17_col6 {
#   background-color: #edeef2;
#   color: #000000;
# }
# #T_12b04_row2_col0 {
#   background-color: #cdd3ee;
#   color: #000000;
# }
# #T_12b04_row2_col1 {
#   background-color: #cfd5ee;
#   color: #000000;
# }
# #T_12b04_row2_col8 {
#   background-color: #a8b4ea;
#   color: #000000;
# }
# #T_12b04_row3_col0 {
#   background-color: #98a7e8;
#   color: #f1f1f1;
# }
# #T_12b04_row3_col2, #T_12b04_row8_col6 {
#   background-color: #ebedf2;
#   color: #000000;
# }
# #T_12b04_row3_col4, #T_12b04_row6_col2, #T_12b04_row13_col4, #T_12b04_row14_col1, #T_12b04_row14_col8 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_12b04_row3_col8 {
#   background-color: #bec7ec;
#   color: #000000;
# }
# #T_12b04_row3_col9, #T_12b04_row4_col3, #T_12b04_row5_col2, #T_12b04_row5_col3, #T_12b04_row7_col0, #T_12b04_row7_col7, #T_12b04_row7_col8, #T_12b04_row9_col2, #T_12b04_row10_col3, #T_12b04_row10_col7, #T_12b04_row13_col5 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_12b04_row4_col2 {
#   background-color: #91a1e7;
#   color: #f1f1f1;
# }
# #T_12b04_row4_col4 {
#   background-color: #95a5e7;
#   color: #f1f1f1;
# }
# #T_12b04_row4_col6 {
#   background-color: #899be6;
#   color: #f1f1f1;
# }
# #T_12b04_row6_col9 {
#   background-color: #b5bfeb;
#   color: #000000;
# }
# #T_12b04_row7_col3 {
#   background-color: #d9ddef;
#   color: #000000;
# }
# #T_12b04_row7_col4 {
#   background-color: #a4b1e9;
#   color: #000000;
# }
# #T_12b04_row7_col5 {
#   background-color: #e9ebf1;
#   color: #000000;
# }
# #T_12b04_row7_col6 {
#   background-color: #a6b3e9;
#   color: #000000;
# }
# #T_12b04_row8_col2 {
#   background-color: #c9d0ee;
#   color: #000000;
# }
# #T_12b04_row8_col4 {
#   background-color: #d7dbef;
#   color: #000000;
# }
# #T_12b04_row9_col1 {
#   background-color: #8c9de6;
#   color: #f1f1f1;
# }
# #T_12b04_row9_col9 {
#   background-color: #acb8ea;
#   color: #000000;
# }
# #T_12b04_row10_col2 {
#   background-color: #b8c1eb;
#   color: #000000;
# }
# #T_12b04_row10_col4 {
#   background-color: #e0e3f0;
#   color: #000000;
# }
# #T_12b04_row10_col8 {
#   background-color: #dde0f0;
#   color: #000000;
# }
# #T_12b04_row12_col2 {
#   background-color: #aebaea;
#   color: #000000;
# }
# #T_12b04_row12_col3 {
#   background-color: #c3cbed;
#   color: #000000;
# }
# #T_12b04_row12_col5 {
#   background-color: #b8c2eb;
#   color: #000000;
# }
# #T_12b04_row14_col9 {
#   background-color: #798ee4;
#   color: #f1f1f1;
# }
# #T_12b04_row15_col0 {
#   background-color: #d5daef;
#   color: #000000;
# }
# #T_12b04_row15_col2 {
#   background-color: #e3e6f1;
#   color: #000000;
# }
# #T_12b04_row15_col6, #T_12b04_row16_col3 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_12b04_row15_col8 {
#   background-color: #92a3e7;
#   color: #f1f1f1;
# }
# #T_12b04_row17_col2 {
#   background-color: #c8cfed;
#   color: #000000;
# }
# #T_12b04_row17_col3 {
#   background-color: #c4cbed;
#   color: #000000;
# }
# #T_12b04_row17_col4 {
#   background-color: #e2e5f1;
#   color: #000000;
# }
# #T_12b04_row17_col5 {
#   background-color: #d1d6ee;
#   color: #000000;
# }
# #T_12b04_row17_col7 {
#   background-color: #d7dcef;
#   color: #000000;
# }
# #T_12b04_row17_col9 {
#   background-color: #e6e8f1;
#   color: #000000;
# }
# </style>
# <table id="T_12b04" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12b04_level0_col0" class="col_heading level0 col0" >airplane</th>
#       <th id="T_12b04_level0_col1" class="col_heading level0 col1" >automobile</th>
#       <th id="T_12b04_level0_col2" class="col_heading level0 col2" >bird</th>
#       <th id="T_12b04_level0_col3" class="col_heading level0 col3" >cat</th>
#       <th id="T_12b04_level0_col4" class="col_heading level0 col4" >deer</th>
#       <th id="T_12b04_level0_col5" class="col_heading level0 col5" >dog</th>
#       <th id="T_12b04_level0_col6" class="col_heading level0 col6" >frog</th>
#       <th id="T_12b04_level0_col7" class="col_heading level0 col7" >horse</th>
#       <th id="T_12b04_level0_col8" class="col_heading level0 col8" >ship</th>
#       <th id="T_12b04_level0_col9" class="col_heading level0 col9" >truck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12b04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12b04_row0_col0" class="data row0 col0" >0.69%</td>
#       <td id="T_12b04_row0_col1" class="data row0 col1" >0.08%</td>
#       <td id="T_12b04_row0_col2" class="data row0 col2" >0.49%</td>
#       <td id="T_12b04_row0_col3" class="data row0 col3" >86.51%</td>
#       <td id="T_12b04_row0_col4" class="data row0 col4" >0.21%</td>
#       <td id="T_12b04_row0_col5" class="data row0 col5" >4.82%</td>
#       <td id="T_12b04_row0_col6" class="data row0 col6" >1.73%</td>
#       <td id="T_12b04_row0_col7"

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog'
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 1/1 [==============================] - 0s 307ms/step
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)

layer_names
# Out:
# ['conv2d',
#  'max_pooling2d',
#  'dropout',
#  'conv2d_1',
#  'max_pooling2d_1',
#  'dropout_1',
#  'conv2d_2',
#  'max_pooling2d_2',
#  'dropout_2',
#  'flatten',
#  'dense',
#  'batch_normalization',
#  'dropout_3',
#  'dense_1']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')

plt.show();
# Out:
# <ipython-input-42-1efdfb529874>:28: RuntimeWarning: invalid value encountered in divide
#   channel_image /= channel_image.std()
# <ipython-input-42-1efdfb529874>:31: RuntimeWarning: invalid value encountered in cast
#   channel_image = np.clip(channel_image, 0, 255).astype('uint8')

# %%
# Time Stamp
current_time = datetime.datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")

# Print the formatted time
print("Last Run:", formatted_time)
# Out:
# Last Run: 2024-05-08 07:23:23
